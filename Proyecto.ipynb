# %% [markdown]
# __Problema__: Encontrar la masa límite de una enana blanca antes de convertirse en una estrella de neutrones o un agujero negro, este límite en la masa es conocido como límite de Chandrasekhar. (Nota: para visualizar de manera correcta todas las ecuaciones puede cargarse el notebook en Jupyter ya que Github,no respeta la sintaxis de LaTeX en algunos casos)

# %% [markdown]
# __ Teoría__

# %% [markdown]
# En teoría cinética podemos encontrar que el número de partículas por unidad en el espacio fase está dada por (densidad numérica):
#
#
# \begin{equation}
# \frac{dN}{d^3x d^3p}=\frac{g}{\hbar^3}f\tag{1}
# \end{equation}
#
# donde $h^3$ es el volumen de la celda en el espacio fase,g es el número de estados de una particula con un determinado momento $p$ y $f$ es el número de ocupación promedio de una celda en el espacio fase.
#
# Además la densidad de partículas en el espacio de momentos está dada por
#
# \begin{equation}
# n=\int\frac{dN}{d^3x d^3p}d^3p\tag{2}
# \end{equation}
#
# Por otra parte la presión de un sistema con una distribución de momentos isotrópica está dada por
#
# \begin{equation}
# P=\frac{1}{3}\int pv\frac{dN}{d^3x d^3p}d^3p\tag{3}
# \end{equation}
#
# Para un gas ideal en equilibrio sabemos que $f$ tiene una forma simple:
#
# \begin{equation}
#     f(E)=\frac{1}{e^{(E-\mu)/kT}\pm 1}\tag{4}
# \end{equation}
#
#
# Para un gas de fermiones completamente degenerado, es decir, con   ($T\rightarrow 0, \frac{\mu}{kT}\rightarrow \infty$) $f(E)$ tiende a las siguientes igualdades:
#
# \begin{equation}
# f(E)=
# \begin{cases}
#       1 & E\leq E_F \\
#       0 & E > E_F
#       \end{cases}\tag{5}
# \end{equation}
#
# para estos gases $\mu$ es llamada la energía de Fermi $E_F$.
#
# __Ecuación de estado de un gas ideal de Fermi completamente degenerado.__
#
# En última instancia una enana blanca o una estrella de neutrones aisladas tienden a enfriarse, es decir, tienden a la temperatura cero, y es la presión asociada a la materia con $T=0$ la que evita que estas estrellas sufran un colapso gravitacional. Es por esta razón que estudiar la ecuación de estado de un gas ideal de Fermi completamente degenerado nos permite tener un modelo sencillo para las estrellas de neutrones y enanas blancas.
#
# Supongamos que tenemos un gas de una sola especia, digamos electrones para los cuales $g=2S+1=2$, de este modo, si definimos el momento de fermi $p_F$ como
#
# \begin{equation}
#  E_F=(p^2_Fc^2+m_ec^4)^\frac{1}{2}\tag{6}
#  \end{equation}
#
#  Tendríamos que $n_e$ está dada por la expresión $(2)$, y sustituyendo $(1)$ se obtiene:
#
#
# \begin{equation}
# n_e=\frac{2}{\hbar^3}\int_0^{p_F}4\pi p^2dp=\frac{8\pi}{3\hbar^3}p_F^3\tag{7}
# \end{equation}
#
#
# Luego definiendo el momento de Fermi adimensional $x_F$ como
#
# \begin{equation}
#  x_F=\frac{p_F}{m_ec}\tag{8}
#  \end{equation}
#
# podemos expresar $n_e$ en términos del momento de fermi adimensional obteniendo
#
#
# \begin{equation}
#  n_e=\frac{1}{3\pi^2\lambda^3_e}x^3\tag{9}
#  \end{equation}
#
# con $\lambda_e=\frac{\hbar}{m_ec}$ la longitud de onda de Compton del electrón.
#
# Así mismo la presión del gas está dada por la siguiente integral
#
# \begin{align}
# P_e=&\frac{1}{3}\frac{2}{\hbar^3}\int_0^{p_F}\frac{p^2c^2}{(p^2_Fc^2+m_ec^4)^\frac{1}{2}}4\pi p^2 dp \\=&\frac{8\pi m^4_ec^5}{3\hbar^3}\int_0^x\frac{x^4}{(1+x^2)^\frac{1}{2}}dx\\=& \frac{m_ec^2}{\lambda^3_e}\phi(x)\tag{10}
# \end{align}
#
#
# donde
#
# \begin{equation}
# \phi(x)=\frac{1}{8\pi^2}[x(1+x^2)^\frac{1}{2}(\frac{2x^2}{3}-1)+ln[x+(1+x^2)^\frac{1}{2}]]\tag{11}
# \end{equation}
#
# en el régimen ultra relativista, es decir cuando $\rho >> 6*10^{15} g cm^{-3}$,
#  $\phi(x) \rightarrow \frac{x^5}{15\pi^2}$ y la presión puede ser escrita en su forma politrópica.
#
#  \begin{equation}
#  P=K\rho^\Gamma\tag{12}
#  \end{equation}
#
#  con $\Gamma=\frac{4}{3}$  y  $K=1.2293*10^{15} cgs$
#
#
#
# __ Ecuación de equilibrio hidrostático__
#
# Si idealizamos la distribución de una estrella de tal manera que tenga simetría esférica entonces la masa de la estrella dentro de un radio r está dada por:
#
# \begin{equation}
# m(r)=\int_0^r \rho 4\pi r^2 dr\tag{13}
# \end{equation}
#
# o en forma diferencial
#
# \begin{equation}
# \frac{dm(r)}{dr}=4\pi r^2 \rho\tag{14}
# \end{equation}
#
#
# Por otra parte si consideramos la atracción gravitacional que siente una masa $dm$ debido a $m(r)$ y la presión neta que se ejerce sobre $dm$, es decir, $-P(r+dr)+P(r)$, luego si tomamos un elemento diferencial de area del fluido $dA$ perpendicular a la dirección radial, tendrémos que en equilibro la fuerza gravitacional y la fuerza debida a la presión que se ejerce deben igualarse y tenemos entonces:
#
# \begin{align}
# \frac{Gm(r)}{r^2}dm=&-[P(r+dr)-P(r)]dA\\
# =&\frac{dP}{dr}dA\\
# \end{align}
#
# Y despejando se obtiene la ecuación de equilibrio hidrostático para la estrella
#
# \begin{equation}
# \frac{dP}{dr}=-\frac{Gm(r)\rho}{r^2}\tag{15}
# \end{equation}
#
#
# Veamos que en general sabemos la presión como función de la densidad, pero esta realación involucra un logaritmo así que no podemos despejar esta ecuación para obtener la densidad, así que las ecuaciones $(14)$ y $(15)$ deben resolverse de manera numérica, esto es, a partir de una densidad central podemos obtener la presión central y con esta usar la ecuación diferencial y obtener un paso de la ecuación de la masa también usando algún método de integración, sin embargo para obtener el siguiente paso cuando resolvemos las ecuaciones simultaneamente debemos tambier obtener la siguiente densidad pues esta depende del radio, eso lo podemos lograr implementando algún método de inversión de ecuaciónes de manera aproximada como lo es el método de Newton.
#
# En lo que sigue implementaremos esta solución computacional, para encontrar el límite de Chandrasekhar, que nos indica la masa con la cual una enana blanca colapsa pues la presión electrónica ya no es capaz de sustentar el empuje gravitacional y la estrella se compacta.

# %% [markdown]
# ###### Solución computacional

# %%
using Plots
using LaTeXStrings
theme(:dark)
include("herramientas.jl") #Algunas herramientas programadas previamente.
#------------------------------------------------------------------------#
#método de Newton implementado para resolver el estado de la enana blanca.
function NEWTON(f,y,xo,h)
    n=0
    while abs(f(xo)-y)>h
        n=n+1
        df=(f(xo+h)-f(xo))/h
        xo=xo-(f(xo)-y)/df
        if n>100
            break
        end
    end
    xo
end
# Out:
# NEWTON (generic function with 1 method)

# %% [markdown]
# __ Constantes __

# %%
MasaSol=1.98855e33 #masa solar
A=12.0 #peso atómico
z=6.0 #número atómico
μ=A/z #peso molecular promedio
UMA=1.6605389e-24 
me=9.11e-28   #masa electron
c=3e10        #velocidad de la luz
h=6.626e-27
hb=h/(2.*pi) #constante de Planck reducida
lc=hb/(me*c) #Longitud de onda de Compton
G=6.67259e-8 #Constante de gravitación universal
rhoC = 3e6   #Densidad central para la estrella
ne = rhoC/me #Densidad de electrones(electrones por unidad de volumen)

#Consideraciones para la ecuación de estado en forma politropica. 
#Caso Ultra relativista 
gur=4.0/3.0
Kur=1.2435e15/μ
ρUR(press)=(press/Kur)^(1/gur)
#Caso no relativista 
PT(y)=Kur*y^(gur)
gnr=5.0/3.0
Knr=1.036e13
# Out:
# 1.036e13

# %%
#Funciones auxiliares

ϕ(x)=(1/(8.*pi^2))*(x*((1+x^2)^(.5))*((2.*x^(2.)/3.)-1.)+log(x+(1+x^2.)^.5))
P(x)=((me*c^2.)/(lc^3.))*ϕ(x) #Presion de la estrella en términos de la xF el momento adimensional de fermi
pF(x)=(abs(3.*pi^2.*(hb^3)*x))^(1./3.) #momento de Fermi
xF(x)=x/(me*c) #momento adimensional de Fermi
Chandrasekhar=ones(4170).*1.43145 #limite de Chandrasekhar
ρNR(press)=μ*(press/Knr)^(1/gnr) #rho aproximada como politropo
neF(x)=(x^3./(3.*pi^2.*hb^3.)) #n en terminos de xF
rhoF(x)=μ*UMA*x #rho en términos del momento adimensional de Fermi
# Out:
# rhoF (generic function with 1 method)

# %% [markdown]
# __Esta función me da la masa ($m$), la presión ($P$) y la densidad ($\rho$) limite de una estrella
# dada la densidad central y la presión central, así como la masa en $r=0$__.

# %%
function Estrella(i,n)
#Valores iniciales
#------------------------------------------------------------------------------#
rhoC = n*10^i #Densidad central para la estrella
ne = rhoC/me #Densidad de electrones(electrones por unidad de volumen)
press = P(xF(pF(ne))) #Presión central de la estrella
n = 0              #contador del método de runge kutta
dr = 1*10^5   #Paso del método de Runge Kutta
r = 0       #radio del método de Runge kutta
m = 0        #masa del método de runge kutta
x = xF(pF(ne)) #Momento correspondiente a la densidad central
#---------------------------------------------------------------------------
M=[] #Arreglo de Masa
R=[] #Arreglo de Radio
Pe=[] #Arreglo de Presión
Rho=[] #Arreglo de densidad
    
#Proceso iterativo del método de Runge Kutta de orden 4    
while press>0
 
 r=r+dr
 n=n+1   
 rho=rhoF(neF(me*c*NEWTON(P,press,x,0.01)))       
 push!(Pe,press)
 push!(Rho,rho)       
     
 
 rho1=rhoF(neF(me*c*NEWTON(P,press,x,0.01))) #Push 
 k1m=(4*pi*(r^2)*rho1)
 M1=m+(k1m*dr*0.5)
 k1p=-(G*m*rho1)/(r^2.)
 P1=press+(k1p*dr*0.5)
 
 
 rho2=rhoF(neF(me*c*NEWTON(P,P1,x,0.01)))
 k2m=(4*pi*((r+dr*0.5)^2)*rho2)
 M2=m+(k2m*dr*0.5)
 k2p=-(G*M1*rho2)/((r+dr*0.5)^2.)
 P2=press+(k2p*dr*0.5)
 
 
 
 
 rho3=rhoF(neF(me*c*NEWTON(P,P2,x,0.01)))   
 k3m=(4*pi*((r+dr*0.5)^2)*rho3)
 M3=m+(k3m*dr*0.5)
 k3p=-(G*(M2)*rho3)/((r+dr*0.5)^2.)
 P3=press+(k3p*dr*0.5)
 
    
 rho4=rhoF(neF(me*c*NEWTON(P,P3,x,0.01)))
 k4m=(4*pi*((r+dr)^2)*rho4)
 k4p=-(G*M3*rho4)/((r+dr)^2.)
 



 
 m=m+(dr/6.)*(k1m+2.*(k2m+k3m)+k4m)
 press=press+(dr/6.)*(k1p+2.*(k2p+k3p)+k4p)
  
    
 push!(M,m/MasaSol)
 push!(R,r/1e5)  
 
    end
R,M,Pe,Rho
end
y = xF(pF(ne));

# %%
#Condiciones centrales
rho=3*10^6
ne = rho/me
presion=P(xF(pF(ne)))
y = xF(pF(ne))
xo=[0.1,presion]

#Sistema de ecuaciones para usarse en un método de Runge Kutta de Cuarto orden previamente creado-----#
f(x,t)=[4*pi*(t^2)*rhoF(neF(me*c*NEWTON(P,x[2],y,0.01))),
    -G*x[1]*rhoF(neF(me*c*NEWTON(P,x[2],y,0.01)))/(t^2)]  
#------------------------------------------------------------------------#
# Resolvemos la ecuación con Runge Kutta 4to orden
s3=herramientas.RungeKutta4th(f,xo,0.1,3e8,1e5)

#-------------------------------------------------------------------------#
# Iterador que crea las listas de Masa,Radio y Presión.
function Listas(s)
listM=[]
listP=[]
listR=[]
for i in 1:length(s[2])
    m=s[2][i][1]
    p=s[2][i][2]
    r=s[1][i]
    if isnan(p)==false || isnan(m)==false
        push!(listM,m/MasaSol)
        push!(listP,p)
        push!(listR,r/1e5)
    end
end
    return listM,listP,listR
end
#--------------------------------#
M3=Listas(s3)[1]
P3=Listas(s3)[2]
R3=Listas(s3)[3];

# %% [markdown]
# __ Resultados__

# %%
plot(Estrella(6,3)[1],Estrella(6,3)[2],ylim=(0,1.5),yticks=(0:.1:1.5),line=:dash,xlabel="R",ylabel="M",label="ρ=3e6")
plot!(Estrella(6,3)[1],Chandrasekhar,ylim=(0,1.5),yticks=(0:.1:1.5),line=:dot,label="Masa límite de Chandrasekhar")
plot!(Estrella(5,3)[1],Estrella(5,3)[2],ylim=(0,1.5),yticks=(0:.1:1.5),line=:dash,label="ρ=3e5")
plot!(Estrella(4,3)[1],Estrella(4,3)[2],ylim=(0,1.5),yticks=(0:.1:1.5),line=:dash,label="ρ=3e4")
plot!(Estrella(7,1)[1],Estrella(7,1)[2],ylim=(0,1.5),yticks=(0:.1:1.5),line=:dash,label="ρ=3e7",title="Limite de Chandrasekhar para una enana blanca")
# Out:
# <img src="data:image/png;base64,..." />

# %%
plot(Estrella(6,3)[1],Estrella(6,3)[2],ylim=(0,1.5),yticks=(0:.1:1.5),line=:dash,xlabel="R",ylabel="M",label="Método RK4th con avance de ρ")
plot!(Estrella(6,3)[1],Chandrasekhar,ylim=(0,1.5),yticks=(0:.1:1.5),line=:line,label="Limite de Chandrasekhar teórico")
plot!(R3,M3,label="Método RK4th sin avanzar ρ",line=:dash,title="Limite de Chandrasekhar para una enana blanca")
# Out:
# <img src="data:image/png;base64,..." />

# %%
plot(Estrella(6,3)[1],Estrella(6,3)[3],xlabel="R",ylabel="P",label="Método RK4th con avance de ρ",yformatter = :scientific)
plot!(R3,P3,label="Método RK4th sin avanzar ρ")
plot!(R3,PT.(Estrella(6,3)[4]),line=:dash,label="Aproximación politrópica Ultra-relativista",title="Presion")
# Out:
# <img src="data:image/png;base64,..." />

# %% [markdown]
# __ Cuantificamos el costo computacional el tiempo de los dos métodos. __

# %%
@time(Estrella(6,3));@time(herramientas.RungeKutta4th(f,xo,0.1,3e8,1e5));
# Out:
#   5.078843 seconds (73.37 M allocations: 1.094 GiB, 10.12% gc time)
#   5.384213 seconds (82.00 M allocations: 1.226 GiB, 10.19% gc time)

# %% [markdown]
# __ Transformada de Fourier discreta (DFT) __
#
# De forma breve una transformada de Fourier nos permite transformar una funcion de una variable digamos $x$ a su variable conjugada, sea esta $y$.
#
# La transformada de fourier discreta es la analoga a la transformada de fourier continua sólo que esta toma un número finito de puntos en un dominio para trasnformarlos facilitando su aplicación con algoritmos computacionales.
#
# La DFT se define como sigue:
#
# $${y}_k= \sum_{n=0}^{N-1} x_n e^{-i~2\pi~k~n~/~N}\tag{1}$$
#
#
# Notemos que si hacemos la expansión para cada $k$ "parecerá" que estamos formando un sistema de ecuaciones para las $y_k$ entonces podemos escribir la DFT como una matriz  $y=M\cdot x$.
#
# La matriz que obtendríamos sería la siguiente:
#
#
# $$\begin{pmatrix}
# y_1 \\
#  y_2 \\
# \vdots \\
#  y_N
# \end{pmatrix}
# =
# \begin{pmatrix}
#   e^{-(1\times1)\frac{i2\pi}{N}} & e^{-(1\times2)\frac{i2\pi}{N}} & \cdots & e^{-(1\times N)\frac{i2\pi}{N}} \\
# e^{-(2\times1)\frac{i2\pi}{N}} & e^{-(2\times2)\frac{i2\pi}{N}} & \cdots & e^{-(2\times N)\frac{i2\pi}{N}}\\
#   \vdots  & \vdots  & \ddots & \vdots  \\
#   e^{-(N\times1)\frac{i2\pi}{N}} & e^{-(N\times2)\frac{i2\pi}{N}} & \cdots & e^{-(N\times N)\frac{i2\pi}{N}}
#  \end{pmatrix}
#  \begin{pmatrix}
# x_1 \\
# x_2 \\
# \vdots \\
# x_N
# \end{pmatrix}
# $$

# %%
function DFT(x)
    
    N = length(x)
    
    M = [exp(-2*im*pi*i*j/N) for i in 0:N-1, j in 0:N-1]
    
    y = M*x
   
    return y
end
# Out:
# DFT (generic function with 1 method)

# %% [markdown]
# __ Transformada de Fourier Rápida (FFT)__
#
# La transformadad de Fourier rápidad tiene este nombre puesto que el algoritmo usado reduce la complejidad del problema computacional que tratamos de resolver al obtener la (DFT) de un arreglo, la complejidad
# de un la DFT es de $N^2$ operaciones mientras que la de la FFT es de $Nlog(N)$.
#
# El algoritmo que se usa se debe a Cooley y Tukey quienes mostraron que al partir la DFT en dos sumas una para los puntos pares y otra para los puntos impares del intervalo y aprovechar las simetrías de la DFT podíamos reducir el número de cálculos necesarios.
#
# Si nos fijamos en los DFT y partimos la suma en términos pares e impares obtendrémos lo siguiente:
#
# $$
# \begin{align*}
# y_k &= \sum_{n=0}^{N-1} x_n  e^{-i2\pi kn/N} \\
#     &= \sum_{m=0}^{N/2 - 1} x_{2m} e^{-i2\pi k(2m)/N} + \sum_{m=0}^{N/2 - 1} x_{2m + 1} e^{-i2\pi k(2m + 1)/N}\\
#     &= \sum_{m=0}^{N/2-1} x_{2m} e^{-i2\pi km/(N/2)} + e^{-i2\pi k/N}\sum_{m=0}^{N/2-1} x_{2m + 1} e^{-i2\pi km/(N/2)}\\&=P_k+e^{-i2\pi k/N}I_k
# \end{align*}
# $$
#
#
# Donde $I_k$ es una DFT par los puntos impares y $P_k$ es una DFT para los términos pares.
#
#
# Ahora probarémos que la DFT es períodica pues, es la simetría que explotaremos al aplicar el algoritmo.
#
# \begin{align}
# y_{k+N}&=\sum_{n=0}^{N-1} x_n e^{-i2\pi(k+N)n/N}\\
# &=\sum_{n=0}^{N-1} x_n e^{-i2\pi k n / N}e^{-i~2\pi kn}\\
# &=\sum_{n=0}^{N-1} x_n e^{-i2\pi kn/N}\\
#  &=y_k
# \end{align}
#
#
# Esto implica que nuestras dos DFT divididas tienen periodicidad, es decir.
#
# \begin{equation}
# I_{k+\frac{N}{2}}=I_{k}\\
# P_{k+\frac{N}{2}}=P_k
# \end{equation}
#
#
# Sin embargo, no hemos asegurado que $y_k$ sea periodica pues tenemos que
#
# $$y_k=P_k+e^{-i2\pi k/N}I_k$$
#
#
# nos falta ver que sucede con la exponencial compleja cuando se traslada el índice
#
# \begin{align}
# e^{-i2\pi (k+\frac{N}{2})/N}&=e^{-i2\pi k/N}e^{-i\pi}\\
# &=-e^{-i2\pi k/N}\\
# \end{align}
#
#
# Usando los resultados anteriores podemos afirmar que partiendo la DFT en sus puntos pares e impares reducimos la complejidad del problema, esto se puede ver como sigue
#
#
# \begin{align}
# y_k=P_k+e^{-i2\pi k/N}I_k\\
# y_{k+\frac{N}{2}}=P_k-e^{-i2\pi k/N}I_k
# \end{align}
#
# pero esta vez usamos una nueva k que toma valores de $[0,\frac{N}{2}]$ y usando la periodicidad podemos calcular el valor de los otros $\frac{N}{2}$, $y_k$ faltantes.

# %%
function FFT(x)
    
    N=length(x)

    
    if N<=4
        
        return DFT(x)
        
    end
        
    X_impares = FFT(x[2:2:N])
    X_pares = FFT(x[1:2:N])

    C = [exp(-2*im*pi*k/N) for k in 0:N-1]
    
    Y = vcat(X_pares + [C[k]*X_impares[k] for k in 1:length(X_impares)], X_pares + [C[k+length(X_pares)]*X_impares[k] for k in 1:length(X_impares)])
    
    
    return Y
end
# Out:
# FFT (generic function with 1 method)

# %%
function IFFT(Y)
    
    N=length(Y)
    
    Y_imag = imag(Y)
    Y_real = real(Y)
    
    x_imag = FFT(Y_real)
    x_real = FFT(-Y_imag)

    X = (x_imag + im * x_real)/N
 
    return X
end
# Out:
# IFFT (generic function with 1 method)

# %% [markdown]
# __ Verificamos si nuestra función está devolviendo el resultado correcto comparando con la función nativa de Julia fft.__

# %%
x = rand(1024);
isapprox(FFT(x),fft(x))
# Out:
# true

# %% [markdown]
# __ Comparamos los costos en tiempo computacional de la transformada de Fourier discreta, la FFT y la fft nativa de Julia. __

# %%
@time(DFT(x));@time(FFT(x));@time(fft(x));
# Out:
#   0.085840 seconds (352 allocations: 16.054 MiB, 12.40% gc time)
#   0.005944 seconds (33.01 k allocations: 1.798 MiB)
#   0.000109 seconds (56 allocations: 35.359 KiB)

# %% [markdown]
# __ Ejemplos __

# %% [markdown]
# La ecuación de Poisson en una dimensión está dada por:
#
# $$\frac{d^2 \phi}{dx^2}=\rho(x)$$
#
# Podemos expresar a $\phi$ y $\rho$ de la siguiente manera:
#
# $$\phi(x) = \frac{1}{\sqrt {2\pi}} \int_{-\infty}^{\infty} \hat{\phi}(k) e^{i k x}dk$$
#
# $$\rho(x) = \frac{1}{\sqrt {2\pi}} \int_{-\infty}^{\infty} \hat{\rho}(k) e^{i k x}dk$$
#
# Por lo que obtenemos la siguiente ecuación en el espacio k:
#
# $$\hat{\phi}(k)=\frac{- \hat{\rho}(k)}{k^2}$$
#
#
# __ Carga centrada en $x=0.5$ en una sola dimensión, y en el intervalo [0,1] __.

# %%
# Parámetros del intervalo en el espacio x
N1 = 2^12
h1 = 1/ N1

# Arreglo en el espacio x
x1 = collect(linspace(h1, 1, N1))

# Arreglo en el espacio k

k1 = [0:N1/2; -N1/2+1:-1]

# Función rho

function ρ(x)
    if abs(x - 0.5) < 0.05
        return 10
    else
        return 0
    end
end

ρv = ρ.(x1)

# Resolvemos en el espacio de Fourier
ϕt = -FFT(ρv) ./ k1.^2
ϕt[1] = 0      #Arreglamos en el caso k=0

# Aplicamos la transformada inversa
phi = real((IFFT(ϕt)))

#Graficamos
plot(x1, phi,label="ϕ",xlabel="x",ylabel=L"\phi(x)" )
scatter!([0.5], [0], label = ("Carga en x=1/2"))
# Out:
# <img src="data:image/png;base64,..." />

# %% [markdown]
# __ Distribución de carga en un plano $[0,1]\times[0,1]$, ecuacion de Poisson en dos dimensiones __.

# %%
# Parámetros del intervalo en el espacio x,y
N2 = 2^7
h2 = 1/ N2

# Arreglo en el espacio x
x2 = collect(linspace(h2, 1, N2))
y2 = collect(linspace(h2, 1, N2))
ρv = zeros(128, 128)
ρv[64, 64], ρv[65, 64], ρv[64, 65], ρv[65, 65] = 10.0, 10.0, 10.0, 10.0  #Delta con la carga

# Arreglo en el espacio k
k2 = [0:N2/2; -N2/2+1:-1]
l2 = [0:N2/2; -N2/2+1:-1]
M1 = [[k,l] for k in k2, l in l2]

# Resolvemos en el espacio de Fourier
ϕt1 = -reshape(FFT(ρv),(128,128))
for i in 1:128
    for j in 1:128
    
        ϕt1[i,j] *= 1/((M1[i,j][1]^2)+ (M1[i,j][2]^2))
    end
ϕt1[1,1] = 0      #Arreglamos en el caso k=0
end

#Aplicamos la transformada inversa
ϕ1 = reshape(real((IFFT(ϕt1))),(128,128));

# %%
theme(:none)
surface(ϕ1,color=:magma,
    title="Solución de la ecuación de Poisson",
     xlabel="x",ylabel="y",zlabel=L"\phi(x,y)")


#En las graficas x,y están escalados de acuerdo al tamaño de la matriz
#sin embargo el dominio para el cual se resolvió es el cuadrado
#unitario en el plano.
# Out:
# <img src="data:image/png;base64,..." />

# %% [markdown]
# __ Ecuación de Poisson de dos distribuciones de carga en el plano __.

# %%
# Parámetros del intervalo en el espacio x,y
N2 = 2^7
h2 = 1/ N2

# Arreglo en el espacio x
x2 = collect(linspace(h2, 1, N2))
y2 = collect(linspace(h2, 1, N2))
ρv = zeros(128, 128)
ρv[34, 34], ρv[35, 34], ρv[35, 34], ρv[35, 35] = 10.0, 10.0, 10.0, 10.0  #Delta con la carga
ρv[84, 84], ρv[85, 84], ρv[85, 84], ρv[85, 85] = 10.0, 10.0, 10.0, 10.0
# Arreglo en el espacio k
k2 = [0:N2/2; -N2/2+1:-1]
l2 = [0:N2/2; -N2/2+1:-1]
M1 = [[k,l] for k in k2, l in l2]

# Resolvemos en el espacio de Fourier
ϕt1 = -reshape(FFT(ρv),(128,128))
for i in 1:128
    for j in 1:128
    
        ϕt1[i,j] *= 1/((M1[i,j][1]^2)+ (M1[i,j][2]^2))
    end
ϕt1[1,1] = 0      #Arreglamos en el caso k=0
end

#Aplicamos la transformada inversa
ϕ1 = reshape(real((IFFT(ϕt1))),(128,128));

# %%
contour(ϕ1,title="Lineas equipotenciales")
# Out:
# <img src="data:image/png;base64,..." />

# %% [markdown]
# __ Ecuación de Poisson para una línea de carga finita en el plano __.

# %%
# Parámetros del intervalo en el espacio x,y
N2 = 2^7
h2 = 1/ N2

# Arreglo en el espacio x
x2 = collect(linspace(h2, 1, N2))
y2 = collect(linspace(h2, 1, N2))
ρv = zeros(128, 128)
for i in 20:100
    ρv[64, i]=-1.0
end

# Arreglo en el espacio k
k2 = [0:N2/2; -N2/2+1:-1]
l2 = [0:N2/2; -N2/2+1:-1]
M1 = [[k,l] for k in k2, l in l2]

# Resolvemos en el espacio de Fourier
ϕt1 = reshape(-FFT(ρv),(128,128))
for i in 1:128
    for j in 1:128
    
        ϕt1[i,j] *= 1/((M1[i,j][1]^2)+ (M1[i,j][2]^2))
    end
ϕt1[1,1] = 0      #Arreglamos en el caso k=0
end

#Aplicamos la transformada inversa
ϕ1 = reshape(real((IFFT(ϕt1))),(128,128))
surface(ϕ1,color=:magma,
    title="Solución de la ecuación de Poisson",
     xlabel="x",ylabel="y",zlabel=L"\phi(x,y)")
# Out:
# <img src="data:image/png;base64,..." />

# %%
contour(ϕ1,title="Lineas equipotenciales")
# Out:
# <img src="data:image/png;base64,..." />

# %% [markdown]
# __ Referencias __
#
# [1] Recuperado de https://en.wikipedia.org/wiki/Cooley–Tukey_FFT_algorithm el Jueves, 23 de Noviembre del 2017.
#
# [2] Shapiro,L.__Black Holes, White Dwarfs and Neutron Stars: The Physics of Compact Objects__.New York: Wiley-VCH.
#
# [3] Recuperado de https://en.wikipedia.org/wiki/Discrete_Fourier_transform el Jueves, 23 de Noviembre del 2017.
#
# [4] Arfken,G.(1985).__Mathematical Methods for Physicist.__ San Diego: Academic Press.
